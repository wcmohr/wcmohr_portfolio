# %% [markdown]
# ###### Imports

# %%
import pandas as pd
import glob

# %%
matches_1968 = pd.read_csv('../tennis_atp/atp_matches_1968.csv')

# %%
atp_matches = glob.glob('../tennis_atp/atp_matches*.csv')

# %%
atp_matches_regular = [file for file in atp_matches if 
                       len(file)== len('../tennis_atp/atp_matches_2019.csv')]
atp_matches_regular.sort()

# %%
matches = pd.read_csv(atp_matches_regular[0])
for file in atp_matches_regular[1:]:
    matches = pd.concat([matches,pd.read_csv(file)])

# %%
matches.shape
# Out:
# (188167, 49)

# %%
sorted_atp

# %%
matches
# Out:
#                             tourney_id                  tourney_name surface  \
# 0                            1968-2029                        Dublin   Grass
# 1                            1968-2029                        Dublin   Grass
# 2                            1968-2029                        Dublin   Grass
# 3                            1968-2029                        Dublin   Grass
# 4                            1968-2029                        Dublin   Grass
# ...                                ...                           ...     ...
# 2911  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2912  2022-M-DC-2022-WG2-PO-GRE-JAM-01  Davis Cup WG2 PO: GRE vs JAM    Clay
# 2913  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2914  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
# 2915  2022-M-DC-2022-WG2-PO-HKG-BEN-01  Davis Cup WG2 PO: HKG vs BEN    Hard
#
#       draw_size tourney_level  tourney_date  match_num  winner_id  \
# 0            32             A      19680708        270     202866
# 1            32             A      19680708        271     126914
# 2            32             A      19680708        272     209523
# 3            32             A      19680708        273     100084
# 4            32             A      19680708        274     100132
# ...         ...           ...           ...        ...        ...
# 2911          4             D      20220304          4     209362
# 2912          4             D      20220304          5     202065
# 2913          4             D      20220304          1     138846
# 2914          4             D      20220304          2     209409
# 2915          4             D      20220304          4     208414
#
#       winner_seed winner_entry  ... l_1stIn l_1stWon  l_2ndWon l_SvGms  \
# 0             NaN          NaN  ...     NaN      NaN       NaN     NaN
# 1             NaN          NaN  ...     NaN      NaN       NaN     NaN
# 2             NaN          NaN  ...     NaN      NaN       NaN     NaN
# 3             NaN          NaN  ...     NaN      NaN       NaN     NaN
# 4             NaN          NaN  ...     NaN      NaN       NaN     NaN
# ...           ...          ...  ...     ...      ...       ...     ...
# 2911          NaN          NaN  ...    68.0     42.0      12.0    10.0
# 2912          NaN          NaN  ...    56.0     40.0      20.0    15.0
# 2913          NaN          NaN  ...    54.0     29.0       8.0    11.0
# 2914          NaN          NaN  ...    39.0     24.0       7.0    10.0
# 2915          NaN          NaN  ...    34.0     24.0      13.0    10.0
#
#       l_bpSaved  l_bpFaced  winner_rank winner_rank_points loser_rank  \
# 0           NaN        NaN          NaN                NaN        NaN
# 1           NaN        NaN          NaN                NaN        NaN
# 2           NaN        NaN          NaN                NaN        NaN
# 3           NaN        NaN          NaN                NaN        NaN
# 4           NaN        NaN          NaN                NaN        NaN
# ...         ...        ...          ...                ...        ...
# 2911       11.0       13.0       1103.0                9.0     1130.0
# 2912        4.0        8.0        808.0               23.0     1390.0
# 2913        6.0       10.0       1059.0               10.0     1881.0
# 2914        5.0        9.0          NaN                NaN        NaN
# 2915        5.0        8.0          NaN                NaN        NaN
#
#      loser_rank_points
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2911               8.0
# 2912               4.0
# 2913               1.0
# 2914               NaN
# 2915               NaN
#
# [188167 rows x 49 columns]
